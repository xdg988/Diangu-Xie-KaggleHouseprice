# %% [markdown]
# # Kaggle：House Price

# %% [markdown]
# ## below are the required libraries, if you want to run my notebook.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import GridSearchCV
from mlxtend.regressor import StackingRegressor

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.svm import SVR, LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
# Out:
# D:\python\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## About data

# %% [markdown]
# Firstly, let's read our training data and testing data.

# %%
train=pd.read_csv('D:/machine-learning/kaggle/houseprice/train.csv')
test=pd.read_csv('D:/machine-learning/kaggle/houseprice/test.csv')
train.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Outliers

# %% [markdown]
# From [documentation](#http://ww2.amstat.org/publications/jse/v19n3/Decock/DataDocumentation.txt), there are some outliers in the training data. So let's find them.

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# At the bottom right, there are two features with large GrLivArea that are of a low SalePrice. They are obviously outliers and we should delete them.

# %%
train=train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)
train.shape
# Out:
# (1458, 81)

# %% [markdown]
# ### Data combination

# %% [markdown]
# Let's take a look at our data, including training data and testing data.

# %%
all_data=pd.concat([train,test],ignore_index=True)
all_data=all_data.drop(['SalePrice','Id'],axis=1)
all_data.head(5)
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       856       854          0   NaN             3     1Fam       TA
# 1      1262         0          0   NaN             3     1Fam       TA
# 2       920       866          0   NaN             3     1Fam       TA
# 3       961       756          0   NaN             3     1Fam       Gd
# 4      1145      1053          0   NaN             4     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2  ...   SaleType ScreenPorch  Street  \
# 0           No       706.0         0.0  ...         WD           0    Pave
# 1           Gd       978.0         0.0  ...         WD           0    Pave
# 2           Mn       486.0         0.0  ...         WD           0    Pave
# 3           No       216.0         0.0  ...         WD           0    Pave
# 4           Av       655.0         0.0  ...         WD           0    Pave
#
#    TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2917 entries, 0 to 2916
# Data columns (total 79 columns):
# 1stFlrSF         2917 non-null int64
# 2ndFlrSF         2917 non-null int64
# 3SsnPorch        2917 non-null int64
# Alley            198 non-null object
# BedroomAbvGr     2917 non-null int64
# BldgType         2917 non-null object
# BsmtCond         2835 non-null object
# BsmtExposure     2835 non-null object
# BsmtFinSF1       2916 non-null float64
# BsmtFinSF2       2916 non-null float64
# BsmtFinType1     2838 non-null object
# BsmtFinType2     2837 non-null object
# BsmtFullBath     2915 non-null float64
# BsmtHalfBath     2915 non-null float64
# BsmtQual         2836 non-null object
# BsmtUnfSF        2916 non-null float64
# CentralAir       2917 non-null object
# Condition1       2917 non-null object
# Condition2       2917 non-null object
# Electrical       2916 non-null object
# EnclosedPorch    2917 non-null int64
# ExterCond        2917 non-null object
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Analysing 'SalePrice'

# %% [markdown]
# Firstly, let's talk about 'SalePrice'

# %%
sns.set_style("whitegrid")
sns.distplot(train['SalePrice'])
plt.show()

# %%
print("Skewness: %f" % train['SalePrice'].skew())
print("Kurtosis: %f" % train['SalePrice'].kurt())
# Out:
# Skewness: 1.881296
# Kurtosis: 6.523067

# %% [markdown]
# From the picture and skewness, it is clear that we should use log transformation to make it normal distribution. In this way, we could make sure that residues are normal distribution and then do reaserch on its statistical diagonis result. After transformation, the skewness is less then 1 and 'SalePrice' is normal distribution.

# %%
y_train=np.log1p(train['SalePrice'])
y_train.astype(float)
sns.set_style("whitegrid")
sns.distplot(y_train)
plt.show()

# %%
print("Skewness: %f" % train['SalePrice'].skew())
print("Kurtosis: %f" % train['SalePrice'].kurt())
# Out:
# Skewness: 1.881296
# Kurtosis: 6.523067

# %% [markdown]
# ### Correlation Matrix

# %%
# %matplotlib inline
corrmat = all_data.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)

# %% [markdown]
# ## Handle missing values

# %% [markdown]
# ### NA values

# %% [markdown]
# There are three categories missing values we should consider.

# %% [markdown]
# *  According to the data discription, some features that have missing values can be filled with 'None' or 0. Then we will replace numeric features missing values with zero and categorical features missing values with 'None'.

# %%
cat_features1={'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','BsmtQual','GarageCond','GarageFinish','GarageQual','GarageType','Alley'
              ,'FireplaceQu','Fence','MiscFeature','PoolQC','MasVnrType'}
num_features1={'BsmtFinSF1','BsmtFinSF2','BsmtFullBath','BsmtHalfBath','BsmtUnfSF','TotalBsmtSF','GarageArea','GarageCars',
               'MasVnrArea'}
for c in cat_features1:
    all_data[c]=all_data[c].fillna('None')
    
for n in num_features1:
    all_data[n]=all_data[n].fillna(0)

# %% [markdown]
# * For other missing values, we cannot get useful information about them. Therefore, we will replace numeric features missing values with median and categorical features missing values with mode.

# %%
cat_features2={'Functional','Electrical','Exterior1st','Exterior2nd','KitchenQual','MSZoning','SaleType','Utilities'}
for c in cat_features2:
    all_data[c]=all_data[c].fillna(all_data[c].mode()[0])
#num_features2={'GarageYrBlt'}
all_data['GarageYrBlt']=all_data['GarageYrBlt'].fillna(all_data['GarageYrBlt'].median())

# %% [markdown]
# * However, we could notice that feature 'LotFrontage' has lots of missing value. Therefore, we group them by feature 'Neighborhood' and then  use median values in each group to fill them.

# %%
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# Let's check if there is any missing value left.

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2917 entries, 0 to 2916
# Data columns (total 79 columns):
# 1stFlrSF         2917 non-null int64
# 2ndFlrSF         2917 non-null int64
# 3SsnPorch        2917 non-null int64
# Alley            2917 non-null object
# BedroomAbvGr     2917 non-null int64
# BldgType         2917 non-null object
# BsmtCond         2917 non-null object
# BsmtExposure     2917 non-null object
# BsmtFinSF1       2917 non-null float64
# BsmtFinSF2       2917 non-null float64
# BsmtFinType1     2917 non-null object
# BsmtFinType2     2917 non-null object
# BsmtFullBath     2917 non-null float64
# BsmtHalfBath     2917 non-null float64
# BsmtQual         2917 non-null object
# BsmtUnfSF        2917 non-null float64
# CentralAir       2917 non-null object
# Condition1       2917 non-null object
# Condition2       2917 non-null object
# Electrical       2917 non-null object
# EnclosedPorch    2917 non-null int64
# ExterCond        2917 non-null object
# ...

# %% [markdown]
# ## Feature engeneering

# %% [markdown]
# ### Features relationship with 'SalePrice'

# %% [markdown]
# In this part, let's take a look at features relationship with 'SalePrice'. Actually from the data description, some numerical features can be transformed into categorical features. Some categorical features can also be transformed into numerical features because they have strong linear ralationship with 'SalePrice'. More specifically, we need to plot those features and observe them.

# %% [markdown]
# Firstly, let's separate our data into numeric features and categories features.

# %%
num_f=all_data.dtypes[all_data.dtypes!=object].index
cat_f=all_data.dtypes[all_data.dtypes==object].index
new_train=all_data[:train.shape[0]]
new_test=all_data[train.shape[0]:]

# %% [markdown]
# * Categorical features

# %%
for c in cat_f:
    sns.boxplot(x=new_train[c],y=train['SalePrice'])
    plt.show()

# %% [markdown]
# * Numerical features

# %%
for n in num_f:
    sns.jointplot(x=new_train[n],y=train['SalePrice'])
    plt.show()

# %% [markdown]
# ### Features convert

# %% [markdown]
# From data description and pictures above, we start to make some transformation between numerical features and categorical features.
# What we should be careful is that it is not a good idea to convert too many features between categorical features and numerical features. Because it will easily lose lots of information in raw training and testing data.
#
#  I got this idea from the [link](#https://datascience.stackexchange.com/questions/9202/categorical-and-ordinal-feature-data-representation-in-regression-analysis/9211#9211) and it said:
#
# "One hot encoding can learn the relationship between the ordinal values more finely, but throws out the information that the variables are related. Similarly, with insufficient data it is more likely to overfit.
# Ordinal variables lessen those problems but at the cost of forcing you to define the interval. There are a number of methods for defining the values of your ordinal variables, like rologit."

# %% [markdown]
# * Categorical features to numerical features

# %%
new_features2={'MSSubClass','MoSold','YrSold'}
for n in new_features2:
    all_data[n]=all_data[n].astype(str)

# %% [markdown]
# * Numerical features to categorical features

# %%
cat_features2={'FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 
               'KitchenQual'}
for c in cat_features2:
    lbl=LabelEncoder()
    lbl.fit(['None','No','Po','Fa','TA','Gd','Ex']) 
    all_data[c] = lbl.transform(list(all_data[c].values))

all_data = all_data.replace({
                "BsmtFinType1": {'None':0 ,'Unf':1 ,'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6},
                "BsmtFinType2": {'None':0 ,'Unf':1 ,'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6},
                "BsmtExposure" : {"None":0,"No" : 1, "Mn" : 2, "Av": 3, "Gd" : 4},
                            })

# %% [markdown]
# ### Skewed features

# %% [markdown]
# As the comments in this [kernel](#https://www.kaggle.com/apapiu/regularized-linear-models) says:
#
# "I log transformed certain features for which the skew was > 0.75. This will make the feature more normally distributed and this makes linear regression perform better - since linear regression is sensitive to outliers. Note that if I used a tree-based model I wouldn't need to transform the variables."
#
# We need to make the numerical features more normally distributed.

# %%
num_f2=all_data.dtypes[all_data.dtypes!=object].index
skewed=all_data[num_f2].skew()
skewed=skewed[skewed>0.75]
skewed_feat=skewed.index

all_data[skewed.index]=np.log1p(all_data[skewed.index])

# %% [markdown]
# Of course, Box Cox transformation is also a good idea. In order to be consistent with the way of transforming 'SalePrice', we decide to use log transformation. More details about Box Cox transformation can be found in this [kernel](#https://www.kaggle.com/serigne/stacked-regressions-top-4-on-leaderboard).

# %% [markdown]
# ### Getting dummy features

# %% [markdown]
# For categorical features, we need to do one-hot encoder for them.

# %%
all_data=pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (2917, 275)

# %% [markdown]
# ### Data scaler

# %% [markdown]
# We also need to use robustscaler in case there are more outliers.

# %%
rbs_x=RobustScaler()
all_data=rbs_x.fit_transform(all_data)
#y_train=rbs_y.fit_transform(y_train.reshape(-1,1))
#y_train=y_train.ravel()

# %% [markdown]
# ## Modeling

# %% [markdown]
# Let's split 'all_data' dataset into training data and testing data.

# %%
X_train = all_data[:train.shape[0]]
X_test = all_data[train.shape[0]:]

# %% [markdown]
# ### Evaluation

# %% [markdown]
# We will use Root-Mean-Sqaured-Error(RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price.

# %%
def cv_score(model):
    mse=-cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    rmse=np.sqrt(mse)
    return rmse

# %% [markdown]
# ### Basic models

# %% [markdown]
# Firstly, we choose some simple models and evaluate them.
# * LinearRegression
# * Ridge
# * Lasso
# * Decision Tree
# * Support Vector Regression
# * Random Forest
# * Gradient Boosting Tree
# * XGBoost
# * Lghtgbm

# %%
base_models=[LinearRegression(),Ridge(),Lasso(), DecisionTreeRegressor(),SVR(),LinearSVR(),RandomForestRegressor(),
            GradientBoostingRegressor(),XGBRegressor(), LGBMRegressor()]
names=['lr','ridge','lasso','dtr','svr','lsvr','rfg','gdbt','xgbr','lgbr']
for name, model in zip(names, base_models):
    score = cv_score(model)
    print("{}: {:.6f}, {:.4f}".format(name,score.mean(),score.std()))
# Out:
# lr: 1041612194.708852, 913750352.5808
# ridge: 0.117940, 0.0074
# lasso: 0.399468, 0.0158
# dtr: 0.197703, 0.0097
# svr: 0.116982, 0.0070
# lsvr: 0.127955, 0.0113
# rfg: 0.146551, 0.0042
# gdbt: 0.122052, 0.0056
# xgbr: 0.123739, 0.0061
# lgbr: 0.126403, 0.0060

# %% [markdown]
# ### Hyperparameters tuning

# %% [markdown]
# From the results above, we could find that some models are not so ideal. So we need to try to tun their hyperparemeters.
# In this part, I will use a package called [Bayesian-Optimization](#https://github.com/fmfn/BayesianOptimization). Since lots of models' hyperparameters need to be tuned, we simply show the final results of hyperparameters tunning below. For more details, you can read this [notebook](#http://localhost:8888/notebooks/HousepriceHyperparameters.ipynb).

# %% [markdown]
# * Ridge

# %%
ridge=Ridge(alpha=32.9363)

score = cv_score(ridge)
print("{}: {:.6f}, {:.4f}".format(ridge,score.mean(),score.std()))
# Out:
# Ridge(alpha=32.9363, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001): 0.114564, 0.0058

# %% [markdown]
# * Lasso

# %%
lasso=Lasso(alpha=0.0001)

score = cv_score(lasso)
print("{}: {:.6f}, {:.4f}".format(lasso,score.mean(),score.std()))
# Out:
# Lasso(alpha=0.0001, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False): 0.115900, 0.0069

# %% [markdown]
# * LinearSVR

# %%
linearSVR=LinearSVR(C=1.8644, epsilon=0.0047)

score = cv_score(linearSVR)
print("{}: {:.6f}, {:.4f}".format(linearSVR,score.mean(),score.std()))
# Out:
# LinearSVR(C=1.8644, dual=True, epsilon=0.0047, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=None, tol=0.0001, verbose=0): 0.132119, 0.0093

# %% [markdown]
# * SVR

# %%
svr=SVR(C=100, epsilon=0.001, gamma=0.0001)

score = cv_score(svr)
print("{}: {:.6f}, {:.4f}".format(svr,score.mean(),score.std()))
# Out:
# SVR(C=100, cache_size=200, coef0=0.0, degree=3, epsilon=0.001, gamma=0.0001,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False): 0.111757, 0.0077

# %% [markdown]
# * Random forest

# %%
rfr=RandomForestRegressor(max_features=0.3938, min_samples_split=2, n_estimators=249)

score = cv_score(rfr)
print("{}: {:.6f}, {:.4f}".format(rfr,score.mean(),score.std()))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.3938, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=249, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False): 0.132911, 0.0070

# %% [markdown]
# * GBDT

# %%
gbdt=GradientBoostingRegressor(n_estimators=249, min_samples_split=21, max_features=0.3671,alpha=0.6999,max_depth=5)

score = cv_score(gbdt)
print("{}: {:.6f}, {:.4f}".format(gbdt,score.mean(),score.std()))
# Out:
# GradientBoostingRegressor(alpha=0.6999, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=5,
#              max_features=0.3671, max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=21,
#              min_weight_fraction_leaf=0.0, n_estimators=249,
#              presort='auto', random_state=None, subsample=1.0, verbose=0,
#              warm_start=False): 0.118347, 0.0084

# %% [markdown]
# * xgboost

# %%
xgbr=XGBRegressor(min_child_weight=19,
                 colsample_bytree=0.3502,
                 max_depth=5,
                 subsample=0.9616,
                 gamma=0.0455,
                 reg_alpha=0.0307)

score = cv_score(xgbr)
print("{}: {:.6f}, {:.4f}".format(xgbr,score.mean(),score.std()))
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.3502,
#        gamma=0.0455, learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min_child_weight=19, missing=None, n_estimators=100, nthread=-1,
#        objective='reg:linear', reg_alpha=0.0307, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=0.9616): 0.119413, 0.0061

# %% [markdown]
# * lightgbm

# %%
lgbr= LGBMRegressor(min_child_weight=9,
                 colsample_bytree=0.6885,
                 num_leaves=327,
                 subsample=0.6977,
                 min_split_gain=0.0042,
                 reg_alpha=0.3788)

score = cv_score(lgbr)
print("{}: {:.6f}, {:.4f}".format(lgbr,score.mean(),score.std()))
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None,
#        colsample_bytree=0.6885, learning_rate=0.1, max_depth=-1,
#        min_child_samples=20, min_child_weight=9, min_split_gain=0.0042,
#        n_estimators=100, n_jobs=-1, num_leaves=327, objective=None,
#        random_state=None, reg_alpha=0.3788, reg_lambda=0.0, silent=True,
#        subsample=0.6977, subsample_for_bin=200000, subsample_freq=1): 0.121438, 0.0060

# %% [markdown]
# ### Bagging & Stacking model

# %% [markdown]
# I have read some great notebooks about this part. Some ideas and code details can be found in this [kernel](#https://www.kaggle.com/serigne/stacked-regressions-top-4-on-leaderboard).

# %% [markdown]
# In this section, we will use model ensemble to improve our base models.

# %% [markdown]
# * Averaging base models

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %% [markdown]
# According to the result of cross validation, we will choose some base models that behave very well as our input models.

# %%
average_models=AveragingModels(models=(ridge, lasso, svr, gbdt))

score = cv_score(average_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1088 (0.0066)

# %% [markdown]
# From models score, it is good te see that average_models improve our prediction scores. This will encourage us to look for more complex models to solve this problems.

# %% [markdown]
# * Complex stacking models

# %% [markdown]
# About complex stacking models, I have tried a lot of methods. What impressed me is a very convenient python package [mlxtend](#https://rasbt.github.io/mlxtend/). Therefore, I decide to choose it as my ways of stacking models. For more theories about stacking models, you can look up this package and it introduces very specifically.
#
# For comparison, 'ridge','gbdt','svr','lasso' will be used as base models. Then we decide to choose respectively 'lgbr' and 'xgbr' as meta models. Let's have a look at the results below.

# %%
stregr1 = StackingRegressor(regressors=[ridge, gbdt, svr,lasso], 
                           meta_regressor=xgbr)

score1 = cv_score(stregr1)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score1.mean(), score1.std()))
# Out:
# Stacking Averaged models score: 0.1116 (0.0064)

# %%
stregr2 = StackingRegressor(regressors=[ridge, gbdt, svr,lasso], 
                           meta_regressor=lgbr)

score2 = cv_score(stregr2)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score2.mean(), score2.std()))
# Out:
# Stacking Averaged models score: 0.1162 (0.0053)

# %% [markdown]
# ## Submit

# %%
lasso.fit(X_train,y_train)
lasso_pred=lasso.predict(X_test)
xgbr.fit(X_train,y_train)
xgbr_y_predict=xgbr.predict(X_test)
average=0.5*lasso_pred+0.5*xgbr_y_predict
average=np.expm1(average)
average=pd.DataFrame({'Id':test['Id'],'SalePrice':average})
average.to_csv('D:/machine-learning/kaggle/houseprice/average1_submission.csv',index=False)

# %%
stregr2.fit(X_train,y_train)
stregr2_pred=stregr2.predict(X_test).astype(float)
stregr2_pred=np.expm1(stregr2_pred)
stregr2_pred=pd.DataFrame({'Id':test['Id'],'SalePrice':stregr2_pred})
stregr2_pred.to_csv('D:/machine-learning/kaggle/houseprice/stregr2_submission.csv',index=False)

# %%
#xgbr=XGBRegressor()
xgbr.fit(X_train,y_train)
xgbr_y_predict=xgbr.predict(X_test).astype(float)
xgbr_y_predict=np.expm1(xgbr_y_predict)
xgbr_submission=pd.DataFrame({'Id':test['Id'],'SalePrice':xgbr_y_predict})
xgbr_submission.to_csv('D:/machine-learning/kaggle/houseprice/xgbr_submission2.csv',index=False)

# %%
gbdt.fit(X_train,y_train)
gbdt_pred=gbdt.predict(X_test).astype(float)
gbdt_pred=np.expm1(gbdt_pred)
gbdt_pred=pd.DataFrame({'Id':test['Id'],'SalePrice':gbdt_pred})
gbdt_pred.to_csv('D:/machine-learning/kaggle/houseprice/gbdt_submission1.csv',index=False)

# %%
#ridge=Ridge(alpha=35)
ridge.fit(X_train,y_train)
ridge_pred=ridge.predict(X_test).astype(float)
ridge_pred=np.expm1(ridge_pred)
ridge_pred=pd.DataFrame({'Id':test['Id'],'SalePrice':ridge_pred})
ridge_pred.to_csv('D:/machine-learning/kaggle/houseprice/ridge_submission.csv',index=False)

# %%
#svr=SVR(kernel='rbf',C=15, epsilon=0.009, gamma=0.0004)
svr.fit(X_train,y_train)
svr_pred=svr.predict(X_test).astype(float)
svr_pred=np.expm1(svr_pred)
svr_pred=pd.DataFrame({'Id':test['Id'],'SalePrice':svr_pred})
svr_pred.to_csv('D:/machine-learning/kaggle/houseprice/svr_submission.csv',index=False)

# %%
#lasso=Lasso(alpha=0.0005, max_iter=10000)
lasso.fit(X_train,y_train)
lasso_pred=lasso.predict(X_test).astype(float)
lasso_pred=np.expm1(lasso_pred)
lasso_pred=pd.DataFrame({'Id':test['Id'],'SalePrice':lasso_pred})
lasso_pred.to_csv('D:/machine-learning/kaggle/houseprice/lasso_submission.csv',index=False)

# %%
lgbr.fit(X_train,y_train)
lgbr_y_predict=lgbr.predict(X_test).astype(float)
lgbr_y_predict=np.expm1(lgbr_y_predict)
lgbr_submission=pd.DataFrame({'Id':test['Id'],'SalePrice':lgbr_y_predict})
lgbr_submission.to_csv('D:/machine-learning/kaggle/houseprice/lgbr_submission.csv',index=False)

# %%
# %store X_train
# %store y_train
# Out:
# Stored 'X_train' (ndarray)
# Stored 'y_train' (Series)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# After submitting some of my results with different models, I got a final rank and my RMSE is 0.11874, which ranked 613/4523(top 13.5%). Since this is the second time I took part in the Kaggle competition, I'm very satisfied with this result. What's more, I learnt a lot from other experts' kernel and was impressed with their codes and feature engineering.
#
# However, I also realised that there were lots of things I need to do to improve my modes.
# * About feature engineering, I think I did not handle these data properly. From some good kernels, I found that feature selection and feature reduction were actually useful. But I did not have enough time to do this and I ignore them. In the future, I may try to use LASSO to do the feature selection and use PCA to reduce features like this [kernel](#https://www.kaggle.com/massquantity/all-you-need-is-pca-lb-0-11421-top-4).
# * Since my limited knowledge about Python's Class and inheriance, I did not try to use Pipeline to encapsulate my code. I found this idea also in the kernel above. Sklearn's Pipeline is really a useful tool if you want to get a good score efficiently. So maybe next time I will learn something about Class and try to use Pipeline.
# * About hyperparameters tuning, it is a exciting thing that I found Bayesian-Optimization methods. But I realise that I did not do enough about XGboost and Lightgbm hyperparameters tuning. Because it's hard to understand their parameters. Maybe next time I will firstly try to learn their theories and then go back to tun their parameters. To be continued.
